# %% [markdown]
# <img src="data:image/png;base64,..." align='left' width=250px;>

# %% [markdown]
# # <center> <b>Análise de Dados IV</b> </center>
# ## <center> <b>Análise Fatorial Exoloratória</b> </center>
#
# ## Gabriel Henrique Alves Silva - 11911GIN013
#
# ## Competências e processos AFE
